# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import pickle 
# %matplotlib inline

# %%
study_filename = "complete_study.pkl"

# %%
with open(study_filename, "rb") as input_stream:
    data = pickle.load(input_stream)

# %%
data.keys()
# Out:
# dict_keys(['random_controls', 'region_experiments', 'uncertainty_experiments', 'input_dims', 'config', 'radii', 'temps'])

# %%
data["radii"], data["temps"]
# Out:
# ([0.02, 0.1, 0.3], [0.01, 1.0, 100.0])

# %%
data["config"]
# Out:
# {'n_samples': 10000,
#  'n_init_pts': 10,
#  'n_iter': 24,
#  'n_trials': 32,
#  'n_test_samples': 1000,
#  'n_dev_samples': 1000,
#  'input_dims': 6,
#  'n_layers': 3,
#  'n_nodes': 16,
#  'batches': 1000,
#  'batch_size': 32,
#  'lr': 0.01}

# %%
data["random_controls"].keys()
# Out:
# dict_keys([2, 6])

# %%
data["random_controls"].values()
# Out:
# dict_values([array([[0.3575182 , 0.11789832, 0.02671959, 0.04067449, 0.01847223,
#         0.02105272, 0.02920201, 0.02446796, 0.12147217, 0.09047579,
#         0.02715537, 0.01940569, 0.02071338, 0.01650092, 0.02039099,
#         0.01934116, 0.02402155, 0.01803966, 0.0157658 , 0.0194047 ,
#         0.01889918, 0.01485118, 0.02146716, 0.01682871],
#        [0.36652088, 0.08724554, 0.09952111, 0.02952667, 0.04055561,
#         0.12093787, 0.02370669, 0.02050955, 0.01901158, 0.01941937,
#         0.01671825, 0.01802788, 0.01865151, 0.0178268 , 0.12215155,
#         0.02332834, 0.015839  , 0.01755751, 0.01729084, 0.01707899,
#         0.01785533, 0.01761416, 0.01783521, 0.02081232],
#        [0.32843119, 0.07002291, 0.05943973, 0.03087721, 0.03754373,
#         0.12318787, 0.03029066, 0.03037967, 0.122766  , 0.0241526 ,
#         0.02023847, 0.12370807, 0.12198016, 0.03674168, 0.01708771,
#         0.02044505, 0.02003721, 0.01579922, 0.02126985, 0.0201627 ,
# ...

# %%
if not os.path.exists("./figures"):
    os.mkdir("./figures")

# %%
def region_config(data):
    for radius in data["radii"]:
        for temp in data["temps"]:
            yield (radius, temp)

# %%
for dim in data["region_experiments"]:
    
    plt.figure(figsize=(8,6))
    for experiment, (radius, temp) in zip(data["region_experiments"][dim], region_config(data)):
        mean = experiment.mean(axis=0)
        std = experiment.std(axis=0)
        npts = data["config"]["n_init_pts"]
        steps = np.arange(npts,npts * (len(mean) + 1), npts)
        label = "(r = {0:4.2f}, T = {1:4.2f})".format(radius, temp)
        plt.plot(steps, mean, label=label, marker="o")
        plt.fill_between(steps, mean-std, mean+std, alpha=0.2)
    
    # Plot random control 
    mean = data["random_controls"][dim].mean(axis=0)
    std = data["random_controls"][dim].std(axis=0)
    plt.plot(steps, mean, label="Random Control", marker="o")
    plt.fill_between(steps, mean-std, mean+std, alpha=0.2)
        
    plt.grid(alpha=0.2)
    plt.legend(frameon=False)
    plt.xlabel("Training Points")
    plt.ylabel("Mean Squared Error (Test)")
    plt.title(f"{dim} Dimensional Regression")
    plt.savefig(f"figures/region_sampling_radius_scan_{dim}d.png", bbox_inches="tight")
    plt.savefig(f"figures/region_sampling_radius_scan_{dim}d.pdf", bbox_inches="tight")

# %%
for dim in data["region_experiments"]:
    
    plt.figure(figsize=(8,6))
    
    experiment = data["uncertainty_experiments"][dim]
    mean = experiment.mean(axis=0)
    std = experiment.std(axis=0)
    npts = data["config"]["n_init_pts"]
    steps = np.arange(npts,npts * (len(mean) + 1), npts)
    plt.plot(steps, mean, label="Uncertainty Sampling", marker="o")
    plt.fill_between(steps, mean-std, mean+std, alpha=0.2)
    
    # Plot random control 
    mean = data["random_controls"][dim].mean(axis=0)
    std = data["random_controls"][dim].std(axis=0)
    plt.plot(steps, mean, label="Random Control", marker="o")
    plt.fill_between(steps, mean-std, mean+std, alpha=0.2)
        
    plt.grid(alpha=0.2)
    plt.legend(frameon=False)
    plt.xlabel("Training Points")
    plt.ylabel("Mean Squared Error (Test)")
    plt.title(f"{dim} Dimensional Regression")
    plt.savefig(f"figures/uncertainty_sampling_{dim}d.png", bbox_inches="tight")
    plt.savefig(f"figures/uncertainty_sampling_{dim}d.pdf", bbox_inches="tight")
